# %%
import pandas as pd
from selenium import webdriver 
from selenium.webdriver.chrome.service import Service 
from selenium.webdriver.common.by import By 
import time

# %%
def inicializa_driver():
    # A classe Service é usada para iniciar uma instância do Chrome Webdriver
    service = Service()

    # webdriver.ChromeOptions é usada para definir a preferência para o browser do chrome
    options = webdriver.ChromeOptions()

    # Inicia-se a instância do Chrome Webdriver com as definidas "options" e "service"
    return webdriver.Chrome(service=service, options=options)

# %%
df = pd.read_excel("./Dados.xlsx")  
df
# Out:
#                             Nome  \
# 0    Adriana Bruscato Bortoluzzo
# 1    Adriana Bruscato Bortoluzzo
# 2    Adriana Bruscato Bortoluzzo
# 3    Adriana Bruscato Bortoluzzo
# 4    Adriana Bruscato Bortoluzzo
# ..                           ...
# 806                Rinaldo Artes
# 807                Rinaldo Artes
# 808                Rinaldo Artes
# 809                Rinaldo Artes
# 810                Rinaldo Artes
#
#                                               Trabalho
# 0    https://repositorio.insper.edu.br/entities/pub...
# 1    https://repositorio.insper.edu.br/entities/pub...
# 2    https://repositorio.insper.edu.br/entities/pub...
# 3    https://repositorio.insper.edu.br/entities/pub...
# 4    https://repositorio.insper.edu.br/entities/pub...
# ..                                                 ...
# 806  https://repositorio.insper.edu.br/entities/pub...
# 807  https://repositorio.insper.edu.br/entities/pub...
# 808  https://repositorio.insper.edu.br/entities/pub...
# 809  https://repositorio.insper.edu.br/entities/pub...
# 810  https://repositorio.insper.edu.br/entities/pub...
#
# [811 rows x 2 columns]

# %%
classificacao = []
data = [] 

driver = inicializa_driver()

for url in df["Trabalho"]:
    driver.get(url)
    time.sleep(0.75)


    try:
        tipo_doc = driver.find_element(
        "xpath",
        "//div[h2[text()='Tipo de documento']]//span").text

        classificacao.append(tipo_doc)
    except:
        classificacao.append("Não foi possível identificar o tipo do trabalho")



    try:    
        data_elem = driver.find_element(
        "xpath",
        "//div[h2[text()='Data']]//span").text
        
        data.append(data_elem)
    except:
        data.append("Não foi possível identificar a data do trabalho")

# %%
df.insert(loc=2, column="Data", value=data)
df.insert(loc=3, column="Categoria", value=classificacao)
df
# Out:
#                             Nome  \
# 0    Adriana Bruscato Bortoluzzo
# 1    Adriana Bruscato Bortoluzzo
# 2    Adriana Bruscato Bortoluzzo
# 3    Adriana Bruscato Bortoluzzo
# 4    Adriana Bruscato Bortoluzzo
# ..                           ...
# 806                Rinaldo Artes
# 807                Rinaldo Artes
# 808                Rinaldo Artes
# 809                Rinaldo Artes
# 810                Rinaldo Artes
#
#                                               Trabalho  \
# 0    https://repositorio.insper.edu.br/entities/pub...
# 1    https://repositorio.insper.edu.br/entities/pub...
# 2    https://repositorio.insper.edu.br/entities/pub...
# 3    https://repositorio.insper.edu.br/entities/pub...
# 4    https://repositorio.insper.edu.br/entities/pub...
# ..                                                 ...
# 806  https://repositorio.insper.edu.br/entities/pub...
# 807  https://repositorio.insper.edu.br/entities/pub...
# 808  https://repositorio.insper.edu.br/entities/pub...
# 809  https://repositorio.insper.edu.br/entities/pub...
# 810  https://repositorio.insper.edu.br/entities/pub...
#
#                                                 Data           Categoria
# 0                                               2021   Artigo Científico
# 1    Não foi possível identificar a data do trabalho  Trabalho de Evento
# 2
# 3                                               2019  Trabalho de Evento
# 4                                               2019  Trabalho de Evento
# ..                                               ...                 ...
# 806                                             2021         Dissertação
# 807                                             2013         Dissertação
# 808                                             2016       Working Paper
# 809                                             2021         Dissertação
# 810                                             2006         Dissertação
#
# [811 rows x 4 columns]

# %%
df.to_excel("Dados Completo.xlsx", index=False)
