# %%
import pandas as pd
from selenium import webdriver 
from selenium.webdriver.chrome.service import Service 
from selenium.webdriver.common.by import By 
import time

# %%
def inicializa_driver():
    # A classe Service é usada para iniciar uma instância do Chrome Webdriver
    service = Service()

    # webdriver.ChromeOptions é usada para definir a preferência para o browser do chrome
    options = webdriver.ChromeOptions()

    # Inicia-se a instância do Chrome Webdriver com as definidas "options" e "service"
    return webdriver.Chrome(service=service, options=options)

# %%
df = pd.read_excel("./Estudos Raciais.xlsx")  
df
# Out:
#                Nome                                           Trabalho
# 0      Aline Durans  https://repositorio.insper.edu.br/entities/pub...
# 1    Alisson Santos  https://repositorio.insper.edu.br/entities/pub...
# 2    Alisson Santos  https://repositorio.insper.edu.br/entities/pub...
# 3    Alisson Santos  https://repositorio.insper.edu.br/entities/pub...
# 4    Alisson Santos  https://repositorio.insper.edu.br/entities/pub...
# ..              ...                                                ...
# 603    Sérgio Firpo  https://repositorio.insper.edu.br/entities/pub...
# 604    Sérgio Firpo  https://repositorio.insper.edu.br/entities/pub...
# 605    Sérgio Firpo  https://repositorio.insper.edu.br/entities/pub...
# 606    Sérgio Firpo  https://repositorio.insper.edu.br/entities/pub...
# 607    Sérgio Firpo  https://repositorio.insper.edu.br/entities/pub...
#
# [608 rows x 2 columns]

# %%
classificacao = []
data = [] 

driver = inicializa_driver()

for url in df["Trabalho"]:
    driver.get(url)
    time.sleep(0.75)


    try:
        tipo_doc = driver.find_element(
        "xpath",
        "//div[h2[text()='Tipo de documento']]//span").text

        classificacao.append(tipo_doc)
    except:
        classificacao.append("Não foi possível identificar o tipo do trabalho")



    try:    
        data_elem = driver.find_element(
        "xpath",
        "//div[h2[text()='Data']]//span").text
        
        data.append(data_elem)
    except:
        data.append("Não foi possível identificar a data do trabalho")

# %%
df.insert(loc=2, column="Data", value=data)
df.insert(loc=3, column="Categoria", value=classificacao)
df
# Out:
#                Nome                                           Trabalho  Data  \
# 0      Aline Durans  https://repositorio.insper.edu.br/entities/pub...  2013
# 1    Alisson Santos  https://repositorio.insper.edu.br/entities/pub...  2024
# 2    Alisson Santos  https://repositorio.insper.edu.br/entities/pub...  2022
# 3    Alisson Santos  https://repositorio.insper.edu.br/entities/pub...  2024
# 4    Alisson Santos  https://repositorio.insper.edu.br/entities/pub...  2024
# ..              ...                                                ...   ...
# 603    Sérgio Firpo  https://repositorio.insper.edu.br/entities/pub...  2021
# 604    Sérgio Firpo  https://repositorio.insper.edu.br/entities/pub...  2018
# 605    Sérgio Firpo  https://repositorio.insper.edu.br/entities/pub...  2010
# 606    Sérgio Firpo  https://repositorio.insper.edu.br/entities/pub...  2015
# 607    Sérgio Firpo  https://repositorio.insper.edu.br/entities/pub...  2019
#
#                           Categoria
# 0                Trabalho de Evento
# 1     Artigo de Periódico Noticioso
# 2              Texto para discussão
# 3             Relatório de pesquisa
# 4             Relatório de pesquisa
# ..                              ...
# 603  Trabalho de Conclusão de Curso
# 604  Trabalho de Conclusão de Curso
# 605            Texto para discussão
# 606               Artigo Científico
# 607  Trabalho de Conclusão de Curso
#
# [608 rows x 4 columns]

# %%
df.to_excel("Estudos Raciais Completo.xlsx", index=False)
