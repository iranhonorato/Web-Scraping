# %%
import pandas as pd
from selenium import webdriver 
from selenium.webdriver.chrome.service import Service 
from selenium.webdriver.common.by import By 
import time

# %%
def inicializa_driver():
    # A classe Service é usada para iniciar uma instância do Chrome Webdriver
    service = Service()

    # webdriver.ChromeOptions é usada para definir a preferência para o browser do chrome
    options = webdriver.ChromeOptions()

    # Inicia-se a instância do Chrome Webdriver com as definidas "options" e "service"
    return webdriver.Chrome(service=service, options=options)

# %%
df = pd.read_excel("./Metricis.xlsx")  
df
# Out:
#                                Nome  \
# 0                    Andrea Minardi
# 1                    Andrea Minardi
# 2                    Andrea Minardi
# 3                    Andrea Minardi
# 4                    Andrea Minardi
# ...                             ...
# 1498             Thomaz Teodorovicz
# 1499             Thomaz Teodorovicz
# 1500             Thomaz Teodorovicz
# 1501  Vitor de Barros Santos Freire
# 1502  Vitor de Barros Santos Freire
#
#                                                Trabalho
# 0     https://repositorio.insper.edu.br/entities/pub...
# 1     https://repositorio.insper.edu.br/entities/pub...
# 2     https://repositorio.insper.edu.br/entities/pub...
# 3     https://repositorio.insper.edu.br/entities/pub...
# 4     https://repositorio.insper.edu.br/entities/pub...
# ...                                                 ...
# 1498  https://repositorio.insper.edu.br/entities/pub...
# 1499  https://repositorio.insper.edu.br/entities/pub...
# 1500  https://repositorio.insper.edu.br/entities/pub...
# 1501  https://repositorio.insper.edu.br/entities/pub...
# 1502  https://repositorio.insper.edu.br/entities/pub...
#
# [1503 rows x 2 columns]

# %%
classificacao = []
data = [] 

driver = inicializa_driver()

for url in df["Trabalho"]:
    driver.get(url)
    time.sleep(0.75)


    try:
        tipo_doc = driver.find_element(
        "xpath",
        "//div[h2[text()='Tipo de documento']]//span").text

        classificacao.append(tipo_doc)
    except:
        classificacao.append("Não foi possível identificar o tipo do trabalho")



    try:    
        data_elem = driver.find_element(
        "xpath",
        "//div[h2[text()='Data']]//span").text
        
        data.append(data_elem)
    except:
        data.append("Não foi possível identificar a data do trabalho")

# %%
df.insert(loc=2, column="Data", value=data)
df.insert(loc=3, column="Categoria", value=classificacao)
df
# Out:
#                                Nome  \
# 0                    Andrea Minardi
# 1                    Andrea Minardi
# 2                    Andrea Minardi
# 3                    Andrea Minardi
# 4                    Andrea Minardi
# ...                             ...
# 1498             Thomaz Teodorovicz
# 1499             Thomaz Teodorovicz
# 1500             Thomaz Teodorovicz
# 1501  Vitor de Barros Santos Freire
# 1502  Vitor de Barros Santos Freire
#
#                                                Trabalho  Data  \
# 0     https://repositorio.insper.edu.br/entities/pub...  2011
# 1     https://repositorio.insper.edu.br/entities/pub...  2012
# 2     https://repositorio.insper.edu.br/entities/pub...  2015
# 3     https://repositorio.insper.edu.br/entities/pub...  2018
# 4     https://repositorio.insper.edu.br/entities/pub...  2018
# ...                                                 ...   ...
# 1498  https://repositorio.insper.edu.br/entities/pub...  2022
# 1499  https://repositorio.insper.edu.br/entities/pub...  2020
# 1500  https://repositorio.insper.edu.br/entities/pub...  2016
# 1501  https://repositorio.insper.edu.br/entities/pub...  2024
# 1502  https://repositorio.insper.edu.br/entities/pub...  2017
#
#                Categoria
# 0      Capítulo de Livro
# 1            Dissertação
# 2     Trabalho de Evento
# 3     Trabalho de Evento
# 4     Trabalho de Evento
# ...                  ...
# 1498   Capítulo de Livro
# 1499   Artigo Científico
# 1500       Working Paper
# 1501                Tese
# 1502   Artigo Científico
#
# [1503 rows x 4 columns]

# %%
df.to_excel("Metricis Completo.xlsx", index=False)
