# %% [markdown]
# # Extração de pesquisas

# %%
import pandas as pd
from selenium import webdriver 
from selenium.webdriver.chrome.service import Service 
from selenium.webdriver.common.by import By 
import time

# %%
def inicializa_driver():
    # A classe Service é usada para iniciar uma instância do Chrome Webdriver
    service = Service()

    # webdriver.ChromeOptions é usada para definir a preferência para o browser do chrome
    options = webdriver.ChromeOptions()

    # Inicia-se a instância do Chrome Webdriver com as definidas "options" e "service"
    return webdriver.Chrome(service=service, options=options)

# %%
driver = inicializa_driver()

url = "https://repositorio.insper.edu.br/home"
driver.get(url)
time.sleep(0.75)

global lista_completa
lista_completa = [] 

def fazer_busca(driver, nome):
    links = []

    # Preenche o campo de busca
    busca_repositorio = driver.find_element(By.CSS_SELECTOR, 'input[data-test="search-box"]')
    busca_repositorio.click()
    busca_repositorio.clear()
    busca_repositorio.send_keys(nome)
    time.sleep(1)

    # Clica no botão de busca
    botao_pesquisar = driver.find_element(By.CSS_SELECTOR, 'button[data-test="search-button"]')
    botao_pesquisar.click()
    time.sleep(2)

    while True:
        try:
            pesquisas = driver.find_elements(By.CSS_SELECTOR, "a.item-list-title")
            lista = [link.get_attribute("href") for link in pesquisas]
            for link in lista:
                if link not in lista_completa:
                    lista_completa.append(link)
                    links.append(link)

            proxima_pagina = driver.find_element(By.CSS_SELECTOR, 'a.page-link[aria-label="Next"]')

            # Verifica se está desabilitado
            if "disabled" in proxima_pagina.get_attribute("class"):
                break

            proxima_pagina.click()
            time.sleep(2)

        except:
            break
    return links

# %%
df = pd.read_excel("../Tratamento de dados/Pesquisadores por área.xlsx")
df
# Out:
#                             Metricis       Estudos Raciais  \
# 0                     Andrea Minardi          Aline Durans
# 1                 Angélica Rotondaro        Alisson Santos
# 2           Carolina Pedrosa de Melo      Alysson Portella
# 3                      Daphne Coelho          Daniel Duque
# 4          Fernanda Kesrouani Lemos           Eloá Davanzo
# 5          Fernando Deodato Domingos    Fillipi Nascimento
# 6                  Frederik Dejonghe  Gabrielle Nascimento
# 7                      Leandro Nardi        Gerrio Barbosa
# 8          Leandro Simões Pongeluppe     Giovana Bigliazzi
# 9                 Ligia Vasconcellos      Lauana Lazaretti
# 10                Marcelo Marchesini        Michael França
# 11              Maria Eduarda Giorgi          Pablo Castro
# 12             Naercio Menezes Filho        Rafael Tavares
# 13  Octavio Augusto Darcie de Barros      Rodrigo Carvalho
# 14          Paulo Furquim de Azevedo          Sérgio Firpo
# ...

# %%
df_metricis = df.iloc[0:22, 0]
df_metricis[3] = "Daphne Quintella Coelho Dutra"
df_metricis[21] = "Vitor de Barros Santos Freire"
df_metricis
# Out:
# 0                       Andrea Minardi
# 1                   Angélica Rotondaro
# 2             Carolina Pedrosa de Melo
# 3        Daphne Quintella Coelho Dutra
# 4            Fernanda Kesrouani Lemos
# 5            Fernando Deodato Domingos
# 6                    Frederik Dejonghe
# 7                        Leandro Nardi
# 8            Leandro Simões Pongeluppe
# 9                   Ligia Vasconcellos
# 10                  Marcelo Marchesini
# 11                Maria Eduarda Giorgi
# 12               Naercio Menezes Filho
# 13    Octavio Augusto Darcie de Barros
# 14            Paulo Furquim de Azevedo
# 15                       Pedro Makhoul
# 16                      Priscila Claro
# 17              Ricardo Paes de Barros
# 18                      Sandro Cabral
# 19            Thais Azevedo dos Santos
# 20                  Thomaz Teodorovicz
# 21       Vitor de Barros Santos Freire
# Name: Metricis, dtype: object

# %%
dict_metricis = {}
for nome in df_metricis:
    dict_metricis[nome] = fazer_busca(driver, nome)
    url = "https://repositorio.insper.edu.br/home"
    driver.get(url)
    time.sleep(0.75)

new_df = {}
new_df["Metricis"] = dict_metricis

# %%
df_estudos_raciais = df.iloc[0:15, 1]
df_estudos_raciais
# Out:
# 0             Aline Durans
# 1           Alisson Santos
# 2         Alysson Portella
# 3             Daniel Duque
# 4             Eloá Davanzo
# 5       Fillipi Nascimento
# 6     Gabrielle Nascimento
# 7           Gerrio Barbosa
# 8        Giovana Bigliazzi
# 9         Lauana Lazaretti
# 10          Michael França
# 11            Pablo Castro
# 12          Rafael Tavares
# 13        Rodrigo Carvalho
# 14            Sérgio Firpo
# Name: Estudos Raciais, dtype: object

# %%
dict_estudos_raciais = {}
for nome in df_estudos_raciais:
    dict_estudos_raciais[nome] = fazer_busca(driver, nome)
    url = "https://repositorio.insper.edu.br/home"
    driver.get(url)
    time.sleep(0.75)

new_df["Estudos Raciais"] = dict_estudos_raciais

# %%
df_dados = df.iloc[0:5, 2]
df_dados
# Out:
# 0    Adriana Bruscato Bortoluzzo
# 1         Hedibert Freitas Lopes
# 2               Jose Heleno Faro
# 3      Paulo Cilas Marques Filho
# 4                  Rinaldo Artes
# Name: Dados, dtype: object

# %%
dict_dados = {}
for nome in df_dados:
    dict_dados[nome] = fazer_busca(driver, nome)
    url = "https://repositorio.insper.edu.br/home"
    driver.get(url)
    time.sleep(0.75)

new_df["Dados"] = dict_dados

# %%
df_NDPI = df.iloc[0:3,3]
df_NDPI
# Out:
# 0              Bruno Kawaoka Komatsu
# 1    Claudia Cerqueira do Nascimento
# 2             Naercio Aquino Menezes
# Name: NDPI, dtype: object

# %%
dict_NDPI = {}
for nome in df_NDPI:
    dict_NDPI[nome] = fazer_busca(driver, nome)
    url = "https://repositorio.insper.edu.br/home"
    driver.get(url)
    time.sleep(0.75)

new_df["NDPI"] = dict_NDPI

# %%
df_estudos_genero = df.iloc[0:5,4]
df_estudos_genero
# Out:
# 0        Ana Paula Rodrigues Diniz
# 1         Bruna Arruda de Oliveira
# 2            Graziela Simone Tonin
# 3       Juliana Miranda Mitkiewicz
# 4    Mariana Chies Santiago Santos
# Name: Estudos de Gênero, dtype: object

# %%
dict_estudos_genero = {}
for nome in df_estudos_genero:
    dict_estudos_genero[nome] = fazer_busca(driver, nome)
    url = "https://repositorio.insper.edu.br/home"
    driver.get(url)
    time.sleep(0.75)

new_df["Estudos de Gênero"] = dict_estudos_genero

# %%
df_politicas = df.iloc[0:9, 5]
df_politicas
# Out:
# 0       Alysson Lorenzon Portella
# 1       Ana Paula Rodrigues Diniz
# 2          Carlos Pignatari Filho
# 3         Gustavo Moreira Tavares
# 4          Juliana Raineri Haddad
# 5    Laura Almeida Ramos de Abreu
# 6                   Laura Machado
# 7            Marcos Chaves Gurgel
# 8           Sergio Pinheiro Firpo
# Name: Política Educacional e Inclusão Produtiva, dtype: object

# %%
dict_politicas = {}
for nome in df_politicas:
    dict_politicas[nome] = fazer_busca(driver, nome)
    url = "https://repositorio.insper.edu.br/home"
    driver.get(url)
    time.sleep(0.75)

new_df["Política Educacional e Inclusão Produtiva"] = dict_politicas

# %%
df_publico = df.iloc[0:4,6]
df_publico
# Out:
# 0         Henrique Yu Jiunn Wang
# 1    Jefferson Oliveira de Moura
# 2       Juliana Costa de Carvalho
# 3        Marcela Garcia Carvalho
# Name: Pessoas no Setor Público, dtype: object

# %%
dict_publico = {}
for nome in df_publico:
    dict_publico[nome] = fazer_busca(driver, nome)
    url = "https://repositorio.insper.edu.br/home"
    driver.get(url)
    time.sleep(0.75)

new_df["Pessoas no Setor Público"] = dict_publico

# %%
df_saude = df.iloc[0:15, 7]
df_saude
# Out:
# 0                 Adriano Dutra Teixeira
# 1             Bruno da Cunha de Oliveira
# 2      Carolina Ribeiro Veronesi Marinho
# 3                Darcio Genicolo Martins
# 4                Isabela Brandão Furtado
# 5                  Ivan Goulart Prenhaca
# 6            Julio Adolfo Zucon Trecenti
# 7        Leticia Faria de Carvalho Nunes
# 8         Marcos Paulo de Lucca Silveira
# 9                        Mariana Puschel
# 10         Mariana Skaf Esteves da Rocha
# 11          Natalia Pires de Vasconcelos
# 12         Paulo de Paiva Rosa de Amaral
# 13                       Vanessa Boarati
# 14    Victor Rangel dos Santos Rodrigues
# Name: Saúde, dtype: object

# %%
dict_saude = {}
for nome in df_saude:
    dict_saude[nome] = fazer_busca(driver, nome)
    url = "https://repositorio.insper.edu.br/home"
    driver.get(url)
    time.sleep(0.75)

new_df["Saúde"] = dict_saude

# %%
linhas = []

for nome, trabalhos in dict_metricis.items():
    for trabalho in trabalhos:
        linhas.append({"Nome": nome, "Trabalho": trabalho})

metricis = pd.DataFrame(linhas)
metricis.to_excel("Metricis.xlsx", index=False)

# %%
linhas = []

for nome, trabalhos in dict_estudos_raciais.items():
    for trabalho in trabalhos:
        linhas.append({"Nome": nome, "Trabalho": trabalho}) 

estudos_raciais = pd.DataFrame(linhas)
estudos_raciais.to_excel("Estudos Raciais.xlsx", index=False)

# %%
linhas = []

for nome, trabalhos in dict_dados.items():
    for trabalho in trabalhos:
        linhas.append({"Nome": nome, "Trabalho": trabalho}) 

dados = pd.DataFrame(linhas)
dados.to_excel("Dados.xlsx", index=False)

# %%
linhas = []

for nome, trabalhos in dict_publico.items():
    for trabalho in trabalhos:
        linhas.append({"Nome": nome, "Trabalho": trabalho}) 

publico = pd.DataFrame(linhas)
publico.to_excel("Pessoas no Setor Público.xlsx", index=False)

# %%
linhas = []

for nome, trabalhos in dict_politicas.items():
    for trabalho in trabalhos:
        linhas.append({"Nome": nome, "Trabalho": trabalho}) 

politicas = pd.DataFrame(linhas)
politicas.to_excel("Política Educacional e Inclusão Produtiva.xlsx", index=False)

# %%
linhas = []

for nome, trabalhos in dict_saude.items():
    for trabalho in trabalhos:
        linhas.append({"Nome": nome, "Trabalho": trabalho}) 

saude = pd.DataFrame(linhas)
saude.to_excel("Saúde.xlsx", index=False)

# %%
linhas = []

for nome, trabalhos in dict_estudos_genero.items():
    for trabalho in trabalhos:
        linhas.append({"Nome": nome, "Trabalho": trabalho}) 

estudos_genero = pd.DataFrame(linhas)
estudos_genero.to_excel("Estudos de Gênero.xlsx", index=False)

# %%
linhas = []

for nome, trabalhos in dict_NDPI.items():
    for trabalho in trabalhos:
        linhas.append({"Nome": nome, "Trabalho": trabalho}) 

ndpi = pd.DataFrame(linhas)
ndpi.to_excel("NDPI.xlsx", index=False)
