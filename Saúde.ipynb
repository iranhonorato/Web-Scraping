# %%
import pandas as pd
from selenium import webdriver 
from selenium.webdriver.chrome.service import Service 
from selenium.webdriver.common.by import By 
import time

# %%
def inicializa_driver():
    # A classe Service é usada para iniciar uma instância do Chrome Webdriver
    service = Service()

    # webdriver.ChromeOptions é usada para definir a preferência para o browser do chrome
    options = webdriver.ChromeOptions()

    # Inicia-se a instância do Chrome Webdriver com as definidas "options" e "service"
    return webdriver.Chrome(service=service, options=options)

# %%
df = pd.read_excel("./Saúde.xlsx")  
df
# Out:
#                                    Nome  \
# 0                Adriano Dutra Teixeira
# 1                Adriano Dutra Teixeira
# 2                Adriano Dutra Teixeira
# 3                Adriano Dutra Teixeira
# 4                Adriano Dutra Teixeira
# ..                                  ...
# 170                     Vanessa Boarati
# 171                     Vanessa Boarati
# 172                     Vanessa Boarati
# 173                     Vanessa Boarati
# 174  Victor Rangel dos Santos Rodrigues
#
#                                               Trabalho
# 0    https://repositorio.insper.edu.br/entities/pub...
# 1    https://repositorio.insper.edu.br/entities/pub...
# 2    https://repositorio.insper.edu.br/entities/pub...
# 3    https://repositorio.insper.edu.br/entities/pub...
# 4    https://repositorio.insper.edu.br/entities/pub...
# ..                                                 ...
# 170  https://repositorio.insper.edu.br/entities/pub...
# 171  https://repositorio.insper.edu.br/entities/pub...
# 172  https://repositorio.insper.edu.br/entities/pub...
# 173  https://repositorio.insper.edu.br/entities/pub...
# 174  https://repositorio.insper.edu.br/entities/pub...
#
# [175 rows x 2 columns]

# %%
classificacao = []
data = [] 

driver = inicializa_driver()

for url in df["Trabalho"]:
    driver.get(url)
    time.sleep(0.75)


    try:
        tipo_doc = driver.find_element(
        "xpath",
        "//div[h2[text()='Tipo de documento']]//span").text

        classificacao.append(tipo_doc)
    except:
        classificacao.append("Não foi possível identificar o tipo do trabalho")



    try:    
        data_elem = driver.find_element(
        "xpath",
        "//div[h2[text()='Data']]//span").text
        
        data.append(data_elem)
    except:
        data.append("Não foi possível identificar a data do trabalho")

# %%
df.insert(loc=2, column="Data", value=data)
df.insert(loc=3, column="Categoria", value=classificacao)
df
# Out:
#                                    Nome  \
# 0                Adriano Dutra Teixeira
# 1                Adriano Dutra Teixeira
# 2                Adriano Dutra Teixeira
# 3                Adriano Dutra Teixeira
# 4                Adriano Dutra Teixeira
# ..                                  ...
# 170                     Vanessa Boarati
# 171                     Vanessa Boarati
# 172                     Vanessa Boarati
# 173                     Vanessa Boarati
# 174  Victor Rangel dos Santos Rodrigues
#
#                                               Trabalho  \
# 0    https://repositorio.insper.edu.br/entities/pub...
# 1    https://repositorio.insper.edu.br/entities/pub...
# 2    https://repositorio.insper.edu.br/entities/pub...
# 3    https://repositorio.insper.edu.br/entities/pub...
# 4    https://repositorio.insper.edu.br/entities/pub...
# ..                                                 ...
# 170  https://repositorio.insper.edu.br/entities/pub...
# 171  https://repositorio.insper.edu.br/entities/pub...
# 172  https://repositorio.insper.edu.br/entities/pub...
# 173  https://repositorio.insper.edu.br/entities/pub...
# 174  https://repositorio.insper.edu.br/entities/pub...
#
#                                                 Data  \
# 0                                               2024
# 1
# 2
# 3
# 4
# ..                                               ...
# 170                                             2021
# 171                                             2020
# 172  Não foi possível identificar a data do trabalho
# 173                                             2020
# 174                                             2023
#
#                           Categoria
# 0    Trabalho de Conclusão de Curso
# 1
# 2
# 3
# 4
# ..                              ...
# 170               Artigo Científico
# 171           Relatório de pesquisa
# 172           Relatório de pesquisa
# 173                     Dissertação
# 174               Capítulo de Livro
#
# [175 rows x 4 columns]

# %%
df.to_excel("Saúde Completo.xlsx", index=False)
